# %%
import pandas as pd

df = pd.read_excel('service_list.xlsx')

# %%
df.columns
# Out:
# Index(['category', 'subcategory', 'name', 'price', 'note', 'vat_name',
#        'vat_proportion', 'non_vat_name'],
#       dtype='object')

# %%
df
# Out:
#     category          subcategory  \
# 0   Coaching     Strategy Meeting
# 1   Coaching  Project Development
# 2   Coaching  Project Development
# 3   Coaching    Skill Development
# 4   Coaching    Skill Development
# ..       ...                  ...
# 75   Private                  NaN
# 76  Discount                  NaN
# 77  Discount                  NaN
# 78  Discount                  NaN
# 79  Discount                  NaN
#
#                                                  name    price  \
# 0                         Strategy Meeting 4 Meetings  26000.0
# 1                     Project Development 10 Meetings  55000.0
# 2             Project Development 10 Meetings (Group)      NaN
# 3   Skill Development 15 Hours [Business and Digit...  42000.0
# 4       Skill Development 15 Hours [Computer Science]  42000.0
# ..                                                ...      ...
# 75                                    English Writing   2500.0
# ...

# %%
df.to_excel('data_service_2.xlsx')
